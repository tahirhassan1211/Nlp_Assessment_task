# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # NLP Basics Assessment

# %% [markdown]
# For this assessment we'll be using the short story [_An Occurrence at Owl Creek Bridge_](https://en.wikipedia.org/wiki/An_Occurrence_at_Owl_Creek_Bridge) by Ambrose Bierce (1890). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/375.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# **1. Create a Doc object from the file `owlcreek.txt`**<br>
# > HINT: Use `with open('../TextFiles/owlcreek.txt') as f:`

# %%
# Enter your code here:
with open("owl_creek.txt",encoding="utf8") as doc:
    for line in doc:
        print(line)
# Out:
# The Project Gutenberg eBook of An Occurrence at Owl Creek Bridge
#
#
#
# This ebook is for the use of anyone anywhere in the United States and
#
# most other parts of the world at no cost and with almost no restrictions
#
# whatsoever. You may copy it, give it away or re-use it under the terms
#
# of the Project Gutenberg License included with this ebook or online
#
# at www.gutenberg.org. If you are not located in the United States,
#
# you will have to check the laws of the country where you are located
#
# before using this eBook.
#
#
#
# Title: An Occurrence at Owl Creek Bridge
#
#
#
#
#
# Author: Ambrose Bierce
#
#
#
# Release date: December 1, 1995 [eBook #375]
#
#                 Most recently updated: April 25, 2022
#
#
#
# Language: English
#
#
#
#
#
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK AN OCCURRENCE AT OWL CREEK BRIDGE ***
#
#
#
#
#
#
#
# An Occurrence at Owl Creek Bridge
#
#
#
# by Ambrose Bierce
#
#
#
# THE MILLENNIUM FULCRUM EDITION, 1988
#
#
#
#
#
#
#
#
#
# I
# ...

# %%
# Run this cell to verify it worked:

with open("owl_creek.txt",encoding="utf8") as f:
     text= f.read()
doc = nlp(text)
print(doc[:36])
# Out:
# The Project Gutenberg eBook of An Occurrence at Owl Creek Bridge
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost

# %% [markdown]
# **2. How many tokens are contained in the file?**

# %%
print(len(doc))
# Out:
# 8464

# %% [markdown]
# **3. How many sentences are contained in the file?**<br>HINT: You'll want to build a list first!

# %%
a=list(doc.sents)
len(a)
# Out:
# 319

# %% [markdown]
# **4. Print the second sentence in the document**<br> HINT: Indexing starts at zero, and the title counts as the first sentence.

# %%
list(doc.sents)[1]
# Out:
# You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org.

# %% [markdown]
# ** 5. For each token in the sentence above, print its `text`, `POS` tag, `dep` tag and `lemma`<br>
# CHALLENGE: Have values line up in columns in the print output.**

# %%
for token in doc:
    print(token.text,token.pos_,token.dep_,token.tag_,token.lemma_)
# Out:
# The DET det DT the
# Project PROPN compound NNP Project
# Gutenberg PROPN compound NNP Gutenberg
# eBook PROPN nsubj NNP eBook
# of ADP prep IN of
# An DET det DT an
# Occurrence PROPN pobj NNP Occurrence
# at ADP prep IN at
# Owl PROPN compound NNP Owl
# Creek PROPN compound NNP Creek
# Bridge PROPN pobj NNP Bridge
#
#
#  SPACE dep _SP
#
#
# This DET det DT this
# ebook NOUN nsubj NN ebook
# is AUX ROOT VBZ be
# for ADP prep IN for
# the DET det DT the
# use NOUN pobj NN use
# of ADP prep IN of
# anyone PRON pobj NN anyone
# anywhere ADV advmod RB anywhere
# in ADP prep IN in
# the DET det DT the
# United PROPN compound NNP United
# States PROPN pobj NNP States
# and CCONJ cc CC and
#
#  SPACE dep _SP
#
# most ADJ amod JJS most
# other ADJ amod JJ other
# parts NOUN conj NNS part
# of ADP prep IN of
# the DET det DT the
# world NOUN pobj NN world
# at ADP prep IN at
# no DET det DT no
# cost NOUN pobj NN cost
# and CCONJ cc CC and
# with ADP conj IN with
# ...

# %%
# CHALLENGE SOLUTION:
for token in doc:
    print(f'{token.text:{12}} {token.pos_:{12}} {token.dep_:{12}} {token.tag_:{12}} {token.lemma_:{12}}')
# Out:
# The          DET          det          DT           the
# Project      PROPN        compound     NNP          Project
# Gutenberg    PROPN        compound     NNP          Gutenberg
# eBook        PROPN        nsubj        NNP          eBook
# of           ADP          prep         IN           of
# An           DET          det          DT           an
# Occurrence   PROPN        pobj         NNP          Occurrence
# at           ADP          prep         IN           at
# Owl          PROPN        compound     NNP          Owl
# Creek        PROPN        compound     NNP          Creek
# Bridge       PROPN        pobj         NNP          Bridge
#
#
#        SPACE        dep          _SP
#
#
# This         DET          det          DT           this
# ebook        NOUN         nsubj        NN           ebook
# is           AUX          ROOT         VBZ          be
# for          ADP          prep         IN           for
# the          DET          det          DT           the
# ...

# %% [markdown]
# **6. Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text**<br>
# HINT: You should include an `'IS_SPACE': True` pattern between the two words!

# %%
# Import the Matcher library:

from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
# Create a pattern and add it to matcher:
pattern1 = [{'LOWER': 'subordinates'}]
pattern2 = [{'LOWER': 'sub'}, {'LOWER': 'ordinates'}]
pattern3 = [{'LOWER': 'sub'}, {'IS_PUNCT': True}, {'LOWER': 'ordinates'}]

matcher.add('SubOrdinates', [pattern1, pattern2, pattern3])

# %%
# Create a list of matches called "found_matches" and print the list:
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(14303298902052182374, 680, 681)]

# %% [markdown]
# **7. Print the text surrounding each found match**

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]  # get string representation
    span = doc[start:end]                    # get the matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 14303298902052182374 SubOrdinates 680 681 subordinates

# %% [markdown]
# **EXTRA CREDIT:<br>Print the *sentence* that contains each found match**

# %%
# Out:
# By diving I could evade the bullets and, swimming
# vigorously, reach the bank, take to the woods and get away home.

# %%
# Out:
# The hunted man saw all this over his shoulder; he was now swimming
# vigorously with the current.

# %% [markdown]
# ### Great Job!
